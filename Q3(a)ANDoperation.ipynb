# %% [markdown]
# # Q3a. AND Operation on image

# %%
from PIL import Image

# %%
img1 = Image.open("img1.jpg")
img2 = Image.open("img2.jpg")

print("IMAGE-1")
display(img1)
print("IMAGE-2")
display(img2)
# Out:
# IMAGE-1
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x405 at 0x1A2173FD9E8>
# IMAGE-2
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x640 at 0x1A2173FBE10>

# %%
for y in range(img1.height):
    for x in range(img1.width):
        pixel1 = img1.getpixel((x,y))
        pixel2 = img2.getpixel((x,y))
        new_pixel = (pixel1[0] & pixel2[0], pixel1[1] & pixel2[1], pixel1[2] & pixel2[2] )
        img2.putpixel((x,y),new_pixel)
#img1.show()
#img2.show()
display(img2)
img2.save("q3a_output.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x640 at 0x1A2173FBE10>
